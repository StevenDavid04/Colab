# %% [markdown]
# <a href="https://colab.research.google.com/github/StevenDavid04/Colab/blob/main/Steven_David_Stats_Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**STA 2023 Midterm Project**

# %%
import numpy as np
import matplotlib.pyplot as plt
#The most important step in any Colab file

# %% [markdown]
# #Part 1: Getting your data

# %%
import pandas as pd
def get_database(url): # This function loads the google spreadsheet
    url_head = "https://docs.google.com/spreadsheets/d/"
    url_foot = "/gviz/tq?tqx=out:csv&sheet="
    url_body = url.split('/')[5]
    sheet_name = "1"
    url_csv = url_head + url_body + url_foot + sheet_name
    df = pd.read_csv(url_csv, sep=',', skiprows=0)
    return df

# %%
url = 'https://docs.google.com/spreadsheets/d/1hdBQr8eIz-DQS_-VW9dqMZOK6b90fEo-DFr2fpkxGOg/edit?usp=sharing'
#I had the hardest time making the link work, but that's because I had forgotten the marks before and after the link

# %%
data = get_database(url)
#For this line of code to work I had to make the spreadsheet link public. Took me like 10 minutes to figure out.

# %%
data
# Out:
#              Timestamp Who is the best Spider-Man?
# 0  10/27/2022 14:31:32    Miles Morales Spider-Man

# %% [markdown]
# Plot your data points

# %%
diameters = np.array([12,9,20,7,2])
circumferences = np.array([38,28,63,22,6])
#assigning the values

# %%
x = np.array([12,9,20,7,2])
y = np.array([38,28,63,22,6])
#At first the graph below wasn't functioning, and that was beacuse I did not define 'D' usoimg this code

# %%
plt.title("Circle Diameter vs Circumference")

plt.xlabel("diameter")
plt.ylabel("circumferences")

plt.plot(x,y,'.');

# %% [markdown]
# #Part 2: Linear Fit

# %%
x = diameters
y = circumferences

# %%
x
# Out:
# array([12,  9, 20,  7,  2])

# %%
m_guess = 0
b_guess = 0
#used to find  more accurate line

# %%
m_guess * x
# Out:
# array([0, 0, 0, 0, 0])

# %%
y_guess = m_guess * x + b_guess

# %%
y_guess
# Out:
# array([0, 0, 0, 0, 0])

# %%
best_loss = 1000000000

best_m = None
best_b = None 

for m_guess in np.linspace(-100,100,100): 
    for b_guess in np.linspace(-100,100,100): #finding 100 integars between -100 and 100

        print("Now Testing: ", m_guess, b_guess)

        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess
# Out:
# Streaming output truncated to the last 5000 lines.
# Now Testing:  1.0101010101010104 -100.0
# Now Testing:  1.0101010101010104 -97.97979797979798
# Now Testing:  1.0101010101010104 -95.95959595959596
# Now Testing:  1.0101010101010104 -93.93939393939394
# Now Testing:  1.0101010101010104 -91.91919191919192
# Now Testing:  1.0101010101010104 -89.8989898989899
# Now Testing:  1.0101010101010104 -87.87878787878788
# Now Testing:  1.0101010101010104 -85.85858585858585
# Now Testing:  1.0101010101010104 -83.83838383838383
# Now Testing:  1.0101010101010104 -81.81818181818181
# Now Testing:  1.0101010101010104 -79.79797979797979
# Now Testing:  1.0101010101010104 -77.77777777777777
# Now Testing:  1.0101010101010104 -75.75757575757575
# Now Testing:  1.0101010101010104 -73.73737373737373
# Now Testing:  1.0101010101010104 -71.71717171717171
# Now Testing:  1.0101010101010104 -69.69696969696969
# Now Testing:  1.0101010101010104 -67.67676767676767
# ...

# %%
y_guess = best_m * x + best_b

plt.plot(x,y_guess,'r');
plt.plot(D,C,'.');
plt.show()

print(best_loss,best_m,best_b)
#Creates a red line estimate that goes theough the graph previously made
# Out:
# 3.583001734516836 3.030303030303031 1.0101010101010104

# %%
plt.title('Linear Fit of Circles')

plt.xlabel('Diameter')
plt.ylabel('Circumference')

# Plot the collected data
plt.plot(D,C,'.', label='Observations')

y_estimate = ...

# Plot the line of best fit
plt.plot(x,y_guess,'r', label=f'Estimate: $y = {...} x + {...}$')

print(best_loss,best_m,best_b)

plt.legend();

#This selection of code reates a red line estimate that goes theough the graph previously made,
# Out:
# 3.583001734516836 3.030303030303031 1.0101010101010104

# %% [markdown]
# The estimated relationship is:
#
# $C = 3.03 D + 1.01$

# %% [markdown]
# #Part 3: Interpretation

# %% [markdown]
# ####Question 1:
# What do $m$ and $b$ represent in these equations?
#
# $m$ represents the slope, while $b$ represents the y-intercept

# %% [markdown]
# ####Question 2:
#
# Guess what the correct values $m$ and $b$ should be.
#
# The value for $m$ should be 1, and for $b$ it should be 3

# %% [markdown]
# ####Question 3:
#
# Does it make sense to include $b$ in the parameters?
#
# It should not make a difference since there would be no circumference if there is no diameter

# %% [markdown]
# #BONUS

# %% [markdown]
# #### Bonus 1: Plot the squared errors from your line of best fit

# %%
plt.title("Linear Fit of Circles")

plt.xlabel("Diameter")
plt.ylabel("Circumference")

y_estimate = ...

plt.plot(x,y_guess,'b.', label=f'Estimate: $y = {...} x + {...}$')

plt.legend();
